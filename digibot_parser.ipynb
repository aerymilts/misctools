# %%
import pandas as pd

# %%
df = pd.read_csv('logs.txt', sep='\t', names=['default'])

# %%
def series_separate_by_types(row):
    """
    Assign values to columns based on type inferred from partial string matches 
    and fill nans otherwise.
    """
    points = None
    cost = None
    transaction = None
    card = None
    date = None
    
    try:
        date = pd.to_datetime(row, format='%d/%m/%Y')
    except:
        pass
    
    if date:
        return date, points, cost, transaction, card
    elif 'DBS Points' in row:
        points = row
    elif 'S$' in row:
        cost = row
    elif 'Card' in row:
        card = row
    else:
        transaction = row
        
    return date, points, cost, transaction, card

# %%
def format_logs(df):
    """
    Align log values 
    """
    data = df['default'].apply(series_separate_by_types).apply(pd.Series)
    new_cols = ['date', 'points', 'cost', 'transaction', 'card']
    data = data.rename(columns={c: cn for c, cn in zip(data.columns, new_cols)})

    for c in data.columns:
        print(data[c].notnull().value_counts())

    for col in data:
        data[col] = data[col][data[col].notnull()].reset_index(drop=True)

    data = data[data.notnull().any(axis=1)]
    data['date'] = pd.to_datetime(data['date'][data['date'].notnull()]).reset_index(drop=True)
    data['points'] = data['points'].apply(lambda r: r.split(' ')[0]).astype(int)
    data['cost'] = data['cost'].str.extract('S\$(.*)', expand=False).astype(float)
    data = data.sort_values('date').reset_index(drop=True)
    
    return data

# %%
df2['points'].sum() + 3293 - 3
# Out:
# 10594

# %%
format_logs(df)
# Out:
# False    604
# True     151
# Name: date, dtype: int64
# False    604
# True     151
# Name: points, dtype: int64
# False    604
# True     151
# Name: cost, dtype: int64
# False    604
# True     151
# Name: transaction, dtype: int64
# False    604
# True     151
# Name: card, dtype: int64
#           date  points     cost                           transaction  \
# 0   2019-03-06       3     5.90           GRAB *GRABFOOD SINGAPORE SG
# 1   2019-03-07       1     1.00           GRAB *GRABFOOD SINGAPORE SG
# 2   2019-03-08       4     7.40           GRAB *GRABFOOD SINGAPORE SG
# 3   2019-03-09      30    50.60   KHANSAMA TANDOORI REST SINGAPORE SG
# 4   2019-03-10      26    26.08      SQ FOOTBATH & SPA JOHOR BAHRU MY
# 5   2019-03-11       1     1.00           GRAB *GRABFOOD SINGAPORE SG
# 6   2019-03-12      22    37.45  RAMEN KEISUKE KANI KIN SINGAPORE SGP
# 7   2019-03-12       4     6.30           GRAB *GRABFOOD SINGAPORE SG
# 8   2019-03-13       3     4.50           GRAB *GRABFOOD SINGAPORE SG
# 9   2019-03-14       5     8.00   GRAB *1552541062385108 SINGAPORE SG
# 10  2019-03-14       4     6.50      GRAB *7696732-8-115 SINGAPORE SG
# 11  2019-03-15     669   669.19                 ALT Ecom Bonus earned
# 12  2019-03-15       3     4.70           GRAB *GRABFOOD SINGAPORE SG
# 13  2019-03-16       4     6.80           GRAB *GRABFOOD SINGAPORE SG
# 14  2019-03-19       4     6.20           GRAB *GRABFOOD SINGAPORE SG
# 15  2019-03-19       4     6.20           GRAB *GRABFOOD SINGAPORE SG
# 16  2019-03-19      -3     6.20           GRAB *GRABFOOD SINGAPORE SG
# 17  2019-03-22       7    13.00      GRAB *7696732-8-126 SINGAPORE SG
# 18  2019-03-22    2260  3768.00   CLEARVISION EYE CLINIC SINGAPORE SG
# 19  2019-03-22      12    20.00      GRAB *7696732-8-127 SINGAPORE SG
# 20  2019-03-24       3     5.90           GRAB *GRABFOOD SINGAPORE SG
# 21  2019-03-25      14    23.55       EYECARE CLINIC SINGAPORE 228 SG
# 22  2019-03-26      56    94.84                   STBILL SINGAPORE SG
# 23  2019-03-27      20    33.75       EYECARE CLINIC SINGAPORE 228 SG
# 24  2019-03-27       0     1.00           GRAB *GRABFOOD SINGAPORE SG
# 25  2019-03-28       3     5.50           GRAB *GRABFOOD SINGAPORE SG
# 26  2019-03-29       5     8.50           GRAB *GRABFOOD SINGAPORE SG
# 27  2019-03-29       2     3.50           GRAB *GRABFOOD SINGAPORE SG
# 28  2019-03-29       3     5.30           GRAB *GRABFOOD SINGAPORE SG
# 29  2019-03-31       8    14.10           GRAB *GRABFOOD SINGAPORE SG
# ..         ...     ...      ...                                   ...
# 121 2019-06-23       8    14.50      GRAB *7696732-8-181 SINGAPORE SG
# 122 2019-06-24     195   195.41      BRITISH A1258794490020 LONDON GB
# 123 2019-06-25       3     5.00      GRAB *7696732-8-182 SINGAPORE SG
# 124 2019-06-29     314   314.48            EASYJET EXDMN8L EASYJET GB
# 125 2019-07-02      23    39.00   FIVE OARS COFFEE ROAST SINGAPORE SG
# 126 2019-07-06     118   118.38      SWISS INT7242316235254 ZURICH CH
# 127 2019-07-06     118   118.38      SWISS INT7242316235251 ZURICH CH
# 128 2019-07-06     118   118.38      SWISS INT7242316235253 ZURICH CH
# 129 2019-07-06     118   118.38      SWISS INT7242316235252 ZURICH CH
# 130 2019-07-11      99   165.47   AIRBNB * HMAHBFHJE5 415-800-5959 GB
# 131 2019-07-13     174   290.48   AIRBNB * HMAJFCBYBP 415-800-5959 GB
# 132 2019-07-15     568   568.16                 ALT Ecom Bonus earned
# 133 2019-07-20      20    33.90   GUARDIAN @313 SOMERSET SINGAPORE SG
# 134 2019-07-27      47    47.39              MY PHARMACY-NB SKUDAI MY
# 135 2019-08-09       0     1.40   COLD STORAGE-SENTOSA C SINGAPORE SG
# 136 2019-08-13       3     6.40          BUS/MRT 8787871 SINGAPORE SG
# 137 2019-08-14       1     2.70          BUS/MRT 8867582 SINGAPORE SG
# 138 2019-08-15     647   647.11                 ALT Ecom Bonus earned
# 139 2019-08-15       1     2.70          BUS/MRT 8970812 SINGAPORE SG
# 140 2019-08-16       2     4.40          BUS/MRT 9029855 SINGAPORE SG
# 141 2019-08-17      34    34.22              UNIQLO-JB JOHOR BAHRU MY
# 142 2019-08-17       0     0.83          BUS/MRT 9129516 SINGAPORE SG
# 143 2019-08-19       2     3.40          BUS/MRT 9285174 SINGAPORE SG
# 144 2019-08-20       1     2.98          BUS/MRT 9338957 SINGAPORE SG
# 145 2019-08-21       1     2.70          BUS/MRT 9486716 SINGAPORE SG
# 146 2019-08-22       1     2.70          BUS/MRT 9524027 SINGAPORE SG
# 147 2019-08-23      23    39.95   PRETTY FIT/BEETLEBUG - SINGAPORE SG
# 148 2019-08-23       2     4.84          BUS/MRT 9613310 SINGAPORE SG
# 149 2019-08-24       2     3.41          BUS/MRT 9731188 SINGAPORE SG
# 150 2019-08-28     189   316.00      TELECOM-SINGTELSHOP SINGAPORE SG
#
#                                  card
# 0    DBS Altitude Visa Signature Card
# 1    DBS Altitude Visa Signature Card
# 2    DBS Altitude Visa Signature Card
# 3    DBS Altitude Visa Signature Card
# 4    DBS Altitude Visa Signature Card
# 5    DBS Altitude Visa Signature Card
# 6    DBS Altitude Visa Signature Card
# 7    DBS Altitude Visa Signature Card
# 8    DBS Altitude Visa Signature Card
# 9    DBS Altitude Visa Signature Card
# 10   DBS Altitude Visa Signature Card
# 11   DBS Altitude Visa Signature Card
# 12   DBS Altitude Visa Signature Card
# 13   DBS Altitude Visa Signature Card
# 14   DBS Altitude Visa Signature Card
# 15   DBS Altitude Visa Signature Card
# 16   DBS Altitude Visa Signature Card
# 17   DBS Altitude Visa Signature Card
# 18   DBS Altitude Visa Signature Card
# 19   DBS Altitude Visa Signature Card
# 20   DBS Altitude Visa Signature Card
# 21   DBS Altitude Visa Signature Card
# 22   DBS Altitude Visa Signature Card
# 23   DBS Altitude Visa Signature Card
# 24   DBS Altitude Visa Signature Card
# 25   DBS Altitude Visa Signature Card
# 26   DBS Altitude Visa Signature Card
# 27   DBS Altitude Visa Signature Card
# 28   DBS Altitude Visa Signature Card
# 29   DBS Altitude Visa Signature Card
# ..                                ...
# 121  DBS Altitude Visa Signature Card
# 122  DBS Altitude Visa Signature Card
# 123  DBS Altitude Visa Signature Card
# 124  DBS Altitude Visa Signature Card
# 125  DBS Altitude Visa Signature Card
# 126  DBS Altitude Visa Signature Card
# 127  DBS Altitude Visa Signature Card
# 128  DBS Altitude Visa Signature Card
# 129  DBS Altitude Visa Signature Card
# 130  DBS Altitude Visa Signature Card
# 131  DBS Altitude Visa Signature Card
# 132  DBS Altitude Visa Signature Card
# 133  DBS Altitude Visa Signature Card
# 134  DBS Altitude Visa Signature Card
# 135  DBS Altitude Visa Signature Card
# 136  DBS Altitude Visa Signature Card
# 137  DBS Altitude Visa Signature Card
# 138  DBS Altitude Visa Signature Card
# 139  DBS Altitude Visa Signature Card
# 140  DBS Altitude Visa Signature Card
# 141  DBS Altitude Visa Signature Card
# 142  DBS Altitude Visa Signature Card
# 143  DBS Altitude Visa Signature Card
# 144  DBS Altitude Visa Signature Card
# 145  DBS Altitude Visa Signature Card
# 146  DBS Altitude Visa Signature Card
# 147  DBS Altitude Visa Signature Card
# 148  DBS Altitude Visa Signature Card
# 149  DBS Altitude Visa Signature Card
# 150  DBS Altitude Visa Signature Card
#
# [151 rows x 5 columns]
# <b>limit_output extension: Maximum message size of 10000 exceeded with 12617 characters</b>

# %%
df2.to_csv('../logs.csv', index=False)
